# %%
import cv2
from canny import run_canny_detector
from utils import load_image, display_image, imshow

# %%
filename = 'Leena.png'
image_input = load_image(filename)
image_edge = run_canny_detector(image_input)
imshow(image_edge, 'Edge Image (Harris)')
# Out:
# C:\Users\abhi\anaconda3\lib\site-packages\matplotlib\text.py:1163: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-798ad2bcf715> in <module>
#       2 image_input = load_image(filename)
#       3 image_edge = run_canny_detector(image_input)
# ----> 4 imshow('Edge Image (Harris)', image_edge)
#
# G:\Github Repo\Canny\utils.py in imshow(im, title, figsize, cmap)
#      75     plt.figure(figsize=figsize)
#      76     plt.title(title)
# ---> 77     plt.imshow(im, cmap=cmap)
#      78     plt.plot()
#      79     plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
# ...
